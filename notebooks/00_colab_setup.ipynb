# %% [markdown]
# # 00 · Colab / local environment setup
# Follow these steps in a fresh Python 3.10 runtime (Colab GPU preferred).

# %%
# If running inside Colab, first install system deps and this package.
# !pip install --quiet --upgrade pip
# !pip install --quiet -e .
# Alternative: clone the repo and install via git URL
# !pip install --quiet git+https://github.com/YOUR_ORG/sitpath-evaluation-suite.git

# %%
import torch
print('Torch version:', torch.__version__)
print('CUDA available:', torch.cuda.is_available())
if torch.cuda.is_available():
    print('GPU:', torch.cuda.get_device_name(0))
else:
    print('⚠️ GPU not detected—switch Colab runtime to GPU for full-speed training.')
