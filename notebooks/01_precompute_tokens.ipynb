# %% [markdown]
# # 01 · Precompute SitPath tokens
# This notebook downloads datasets (if needed) and caches symbolic tokens so model training on Colab can skip heavy preprocessing.

# %%
# Optional: mount Google Drive to persist cache/outputs across sessions
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# Clone (or pull) the SitPath Evaluation Suite repo
# !git clone https://github.com/YOUR_ORG/sitpath-evaluation-suite.git || true
# %cd sitpath-evaluation-suite

# %%
# !pip install --quiet -e .

# %% [markdown]
# ## Download datasets (runs bash helpers; nuScenes requires manual creds)

# %%
# !make data

# %% [markdown]
# ## Tokenize each dataset (ETH/UCY, SDD-mini, nuScenes-mini)

# %%
# !python scripts/precompute_tokens.py --cfg configs/eth_ucy/sitpath_transformer.yaml
# !python scripts/precompute_tokens.py --cfg configs/sdd_mini/sitpath_transformer.yaml
# !python scripts/precompute_tokens.py --cfg configs/nuscenes_mini/sitpath_transformer.yaml
