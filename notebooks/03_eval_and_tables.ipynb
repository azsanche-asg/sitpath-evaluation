# %% [markdown]
# # 03 · Evaluate models and compose tables

# %%
# %cd /content/sitpath-evaluation-suite

# %% [markdown]
# ## Run test-set evaluation for all ETH/UCY models

# %%
# !python scripts/evaluate.py --cfg configs/eth_ucy/coord_transformer.yaml --split test --save_csv tables/results_coord_transformer.csv
# !python scripts/evaluate.py --cfg configs/eth_ucy/sitpath_transformer.yaml --split test --save_csv tables/results_sitpath_transformer.csv
# !python scripts/evaluate.py --cfg configs/eth_ucy/coord_gru.yaml --split test --save_csv tables/results_coord_gru.csv
# !python scripts/evaluate.py --cfg configs/eth_ucy/sitpath_gru.yaml --split test --save_csv tables/results_sitpath_gru.csv
# !python scripts/evaluate.py --cfg configs/eth_ucy/raster_gru.yaml --split test --save_csv tables/results_raster_gru.csv
# !python scripts/evaluate.py --cfg configs/eth_ucy/social_lstm.yaml --split test --save_csv tables/results_social_lstm.csv

# %% [markdown]
# ## Compose paper tables (CSV + Markdown)

# %%
# !python sitpath_eval/tables_figs/make_tables.py

# %% [markdown]
# ## Preview table artifacts

# %%
import pandas as pd
from pathlib import Path
table_path = Path('tables/table_1.csv')
display(pd.read_csv(table_path))
md_path = Path('tables/table_1.md')
print(md_path.read_text())
