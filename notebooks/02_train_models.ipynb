# %% [markdown]
# # 02 · Train matched-capacity models on ETH/UCY
# Assumes tokens/datasets already cached (see notebook 01).

# %%
# %cd /content/sitpath-evaluation-suite

# %%
# !python scripts/train.py --cfg configs/eth_ucy/coord_transformer.yaml

# %%
# !python scripts/train.py --cfg configs/eth_ucy/sitpath_transformer.yaml

# %%
# !python scripts/train.py --cfg configs/eth_ucy/coord_gru.yaml

# %%
# !python scripts/train.py --cfg configs/eth_ucy/sitpath_gru.yaml

# %%
# !python scripts/train.py --cfg configs/eth_ucy/raster_gru.yaml

# %%
# !python scripts/train.py --cfg configs/eth_ucy/social_lstm.yaml
